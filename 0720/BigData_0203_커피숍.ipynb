# %%
#ms949
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'C:\Apps\temp\data\data_coffee.csv', encoding='ms949')
data
# Out:
#        number          companyName  \
# 0           1    #11(Sharp eleven)
# 1           2    ( 주)커피빈코리아청주지웰시티점
# 2           3             (aA)더블에이
# 3           4             (강서)카페치따
# 4           5          (로즈버드)명동아바타
# ...       ...                  ...
# 46827   46828  美칠커피(MICILL COFFEE)
# 46828   46829          逍遊遙(소유요)커피숍
# 46829   46830                李家고로케
# 46830   46831               至忍플로레죵
# 46831   46832               香'S 카페
#
#                                                   adress  \
# 0           서울특별시 양천구 목동 956번지 롯데캐슬위너 상가동 107호(한두3길 44)
# 1      충청북도 청주시 흥덕구 복대동 3379번지 신영지웰시티1차상업시설 124-1, 12...
# 2                                경상북도 경산시 사동 39번지 108-2호
# 3        서울특별시 강서구 등촌동 63-12번지 외 2필지 어위쉬예다인 (지상 1층) 104호
# 4                      서울특별시 중구 명동2가 83-5번지 (아바타1층1218)
# ...                                                  ...
# 46827                              서울특별시 마포구 상암동 1605번지
# 46828                      충청남도 홍성군 홍성읍 월산리 847-1번지 303호
# ...

# %%
data.head()
# Out:
#               companyName                                             adress  \
# number
# 1       #11(Sharp eleven)       서울특별시 양천구 목동 956번지 롯데캐슬위너 상가동 107호(한두3길 44)
# 2       ( 주)커피빈코리아청주지웰시티점  충청북도 청주시 흥덕구 복대동 3379번지 신영지웰시티1차상업시설 124-1, 12...
# 3                (aA)더블에이                            경상북도 경산시 사동 39번지 108-2호
# 4                (강서)카페치따    서울특별시 강서구 등촌동 63-12번지 외 2필지 어위쉬예다인 (지상 1층) 104호
# 5             (로즈버드)명동아바타                  서울특별시 중구 명동2가 83-5번지 (아바타1층1218)
#
#                                            adressBystreet  dateOflicensing  \
# number
# 1       서울특별시 양천구 목동중앙북로 38 (목동,롯데캐슬위너 상가동 107호(한두3길 44))         20080917
# 2       충청북도 청주시 흥덕구 대농로 17 (복대동,신영지웰시티1차상업시설 124-1, 1...         20101124
# 3                       경상북도 경산시 백자로10길 3-11, 108-2호 (사동)         20130902
# 4             서울특별시 강서구 양천로 452, 1층 104호 (등촌동, 3동 어위쉬예다인)         20121108
# 5                                                     NaN         20020911
#
# ...

# %%
data.set_index('number', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-7c37b50698e9> in <module>
# ----> 1 data.set_index('number', inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['number'] are in the columns"

# %%
data
# Out:
#                 companyName  \
# number
# 1         #11(Sharp eleven)
# 2         ( 주)커피빈코리아청주지웰시티점
# 3                  (aA)더블에이
# 4                  (강서)카페치따
# 5               (로즈버드)명동아바타
# ...                     ...
# 46828   美칠커피(MICILL COFFEE)
# 46829           逍遊遙(소유요)커피숍
# 46830                 李家고로케
# 46831                至忍플로레죵
# 46832                香'S 카페
#
#                                                    adress  \
# number
# 1            서울특별시 양천구 목동 956번지 롯데캐슬위너 상가동 107호(한두3길 44)
# 2       충청북도 청주시 흥덕구 복대동 3379번지 신영지웰시티1차상업시설 124-1, 12...
# 3                                 경상북도 경산시 사동 39번지 108-2호
# 4         서울특별시 강서구 등촌동 63-12번지 외 2필지 어위쉬예다인 (지상 1층) 104호
# 5                       서울특별시 중구 명동2가 83-5번지 (아바타1층1218)
# ...                                                   ...
# 46828                               서울특별시 마포구 상암동 1605번지
# 46829                       충청남도 홍성군 홍성읍 월산리 847-1번지 303호
# 46830                              경상북도 경주시 황성동 472-41번지
# ...

# %%
data.loc[:, ['companyName', 'sizeOfsite']]
# Out:
#                 companyName  sizeOfsite
# number
# 1         #11(Sharp eleven)       20.80
# 2         ( 주)커피빈코리아청주지웰시티점      212.72
# 3                  (aA)더블에이       20.04
# 4                  (강서)카페치따       64.17
# 5               (로즈버드)명동아바타       11.40
# ...                     ...         ...
# 46828   美칠커피(MICILL COFFEE)       30.61
# 46829           逍遊遙(소유요)커피숍       44.21
# 46830                 李家고로케       35.70
# 46831                至忍플로레죵       46.20
# 46832                香'S 카페      176.49
#
# [46832 rows x 2 columns]

# %%
data[data['sizeOfsite'].notnull()]
# Out:
#                 companyName  \
# number
# 1         #11(Sharp eleven)
# 2         ( 주)커피빈코리아청주지웰시티점
# 3                  (aA)더블에이
# 4                  (강서)카페치따
# 5               (로즈버드)명동아바타
# ...                     ...
# 46828   美칠커피(MICILL COFFEE)
# 46829           逍遊遙(소유요)커피숍
# 46830                 李家고로케
# 46831                至忍플로레죵
# 46832                香'S 카페
#
#                                                    adress  \
# number
# 1            서울특별시 양천구 목동 956번지 롯데캐슬위너 상가동 107호(한두3길 44)
# 2       충청북도 청주시 흥덕구 복대동 3379번지 신영지웰시티1차상업시설 124-1, 12...
# 3                                 경상북도 경산시 사동 39번지 108-2호
# 4         서울특별시 강서구 등촌동 63-12번지 외 2필지 어위쉬예다인 (지상 1층) 104호
# 5                       서울특별시 중구 명동2가 83-5번지 (아바타1층1218)
# ...                                                   ...
# 46828                               서울특별시 마포구 상암동 1605번지
# 46829                       충청남도 홍성군 홍성읍 월산리 847-1번지 303호
# 46830                              경상북도 경주시 황성동 472-41번지
# ...

# %%
sr = df.sizeOfsite
sr
# Out:
# number
# 1         20.80
# 2        212.72
# 3         20.04
# 4         64.17
# 5         11.40
#           ...
# 46828     30.61
# 46829     44.21
# 46830     35.70
# 46831     46.20
# 46832    176.49
# Name: sizeOfsite, Length: 46832, dtype: float64

# %%
sr.describe()
# Out:
# count    46813.000000
# mean        75.531012
# std        135.088745
# min          0.000000
# 25%         28.120000
# 50%         50.000000
# 75%         93.750000
# max      24075.000000
# Name: sizeOfsite, dtype: float64

# %%
sr.shape # ,뒤에 숫자가 없는 이유는 결측치 때문
# Out:
# (46832,)

# %%
sr.isnull().sum() # 결측치의 개수
# Out:
# 19

# %%
sr.isnull().mean()
# Out:
# 0.0004057055005124701

# %%
sr.dropna(inplace=True) #inplace로 항구적으로 변경

# %%
sr.shape
# Out:
# (46813,)

# %%
sr.describe()
# Out:
# count    46813.000000
# mean        75.531012
# std        135.088745
# min          0.000000
# 25%         28.120000
# 50%         50.000000
# 75%         93.750000
# max      24075.000000
# Name: sizeOfsite, dtype: float64

# %%
plt.hist(sr, bins=50, color='green', alpha=0.5, density=True)
plt.show()

# %%
sr.median()
# Out:
# 51.76

# %%
sr = sr[sr<500]

# %%
sr.shape
# Out:
# (45360,)

# %%
sr.plot.hist(bins=50, color='purple', )

# %%
plt.hist(np.log(sr), bins=50, color='green', alpha=0.5, density=True)
plt.show()

# %%
sr = sr[sr>0.0]
