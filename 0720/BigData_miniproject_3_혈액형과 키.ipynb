# %%
# 두 가지로 풀어보기
# groupby 메서드 사용
# pivot table 메서드 사용

# data_studentlist_en.scv를 읽어온다.
# 혈액형 별 키를 구한다.

# %%
import pandas as pd 
import numpy as np
import os

# %%
df = pd.read_csv(r'C:\Apps\temp\data_studentlist_en.csv')
df
# Out:
#                 name gender  age  grade absence bloodtype  height  weight
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# ...

# %%
df.head()
# Out:
#               name gender  age  grade absence bloodtype  height  weight
# 0    Jared Diamond      M   23      3       Y         O   165.3    68.2
# 1   Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 2     Brian Martin      M   24      4       N         B   175.0    80.1
# 3     David Hassel      M   23      3       N        AB   182.1    85.7
# 4  Clara Rodriquez      F   20      1       Y         A   168.0    49.5

# %%
df.groupby('bloodtype').height.mean()
# Out:
# bloodtype
# A     169.075
# AB    177.400
# B     171.280
# O     165.140
# Name: height, dtype: float64

# %%
df.groupby('bloodtype')['height'].mean()
# Out:
# bloodtype
# A     169.075
# AB    177.400
# B     171.280
# O     165.140
# Name: height, dtype: float64

# %%
df.groupby('bloodtype')[['height']].mean()
# Out:
#             height
# bloodtype
# A          169.075
# AB         177.400
# B          171.280
# O          165.140

# %%
df.pivot_table(index='bloodtype', values='height')
# Out:
#             height
# bloodtype
# A          169.075
# AB         177.400
# B          171.280
# O          165.140

# %%
df.pivot_table(columns='bloodtype', values='height')
# Out:
# bloodtype        A     AB       B       O
# height     169.075  177.4  171.28  165.14
